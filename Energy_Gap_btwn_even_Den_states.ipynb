# %%
import sympy as sp

# Define symbolic variables
D, B = sp.symbols('D B', real=True)  # Electric and Magnetic Fields
d_eff = sp.Symbol('d_eff', real=True)  # Effective interlayer distance
kB = sp.Symbol('k_B', real=True)  # Boltzmann constant
muB = sp.Symbol('mu_B', real=True)  # Bohr magneton
e = sp.Symbol('e', real=True)  # Elementary charge
m_eff = sp.Symbol('m_eff', real=True)  # Effective mass
epsilon = sp.Symbol('epsilon', real=True)  # Dielectric constant
gamma_1 = sp.Symbol('gamma_1', real=True)
hbar = sp.Symbol('hbar', real=True)
nu = sp.Symbol('nu', real = True)
omega_B = sp.Symbol('omega_B', real=True)
n = sp.Symbol('n', real=True)
l_b = sp.Symbol('l_B', real=True)

# %%
# Define Splittings
Delta_KK = e * D * d_eff  # Valley splitting due to displacement field
Delta_01 = e * B / m_eff  # Orbital splitting in bilayer graphene
Delta_spin = muB * B  # Spin splitting due to Zeeman effect
Delta_ex = sp.Symbol('\Delta_{ex}' )  # Exchange energy
# Out:
# <>:5: SyntaxWarning: invalid escape sequence '\D'
# <>:5: SyntaxWarning: invalid escape sequence '\D'
# C:\Users\gupt1\AppData\Local\Temp\ipykernel_13896\2922866409.py:5: SyntaxWarning: invalid escape sequence '\D'
#   Delta_ex = sp.Symbol('\Delta_{ex}' )  # Exchange energy

# %%
# Define Hamiltonian (4x4 matrix in valley-spin basis)
H = sp.Matrix([
    [Delta_01 + Delta_KK + Delta_spin + Delta_ex, hbar*omega_B*sp.sqrt(n), 0, 0],
    [hbar*omega_B*sp.sqrt(n), Delta_01 + Delta_KK + Delta_spin + Delta_ex, gamma_1, 0],
    [0, gamma_1, - Delta_01 - Delta_KK + Delta_spin - Delta_ex, hbar*omega_B*sp.sqrt(n+1)],
    [0, 0, hbar*omega_B*sp.sqrt(n+1), - Delta_01 - Delta_KK + Delta_spin - Delta_ex]
])

# Compute eigenvalues (energy levels)
eigenvals = H.eigenvals()
eigenvals_expr = [ev for ev in eigenvals]

# %%
H ## Hamiltonian
# Out:
# Matrix([
# [B*e/m_eff + B*mu_B + D*d_eff*e + \Delta_{ex},                         hbar*sqrt(n)*omega_B,                                             0,                                             0],
# [                        hbar*sqrt(n)*omega_B, B*e/m_eff + B*mu_B + D*d_eff*e + \Delta_{ex},                                       gamma_1,                                             0],
# [                                           0,                                      gamma_1, -B*e/m_eff + B*mu_B - D*d_eff*e - \Delta_{ex},                      hbar*omega_B*sqrt(n + 1)],
# [                                           0,                                            0,                      hbar*omega_B*sqrt(n + 1), -B*e/m_eff + B*mu_B - D*d_eff*e - \Delta_{ex}]])

# %%
eigenvals_expr[0]
# Out:
# Piecewise((B*mu_B - sqrt(4*B**2*mu_B**2 - 2*(-(-6*B**2*mu_B**2 + (-16*pi**2*B**2*e**2*epsilon**2*l_B**2 + 48*pi**2*B**2*epsilon**2*l_B**2*m_eff**2*mu_B**2 - 32*pi**2*B*D*d_eff*e**2*epsilon**2*l_B**2*m_eff - 8*pi*B*e**3*epsilon*l_B*m_eff - 16*pi**2*D**2*d_eff**2*e**2*epsilon**2*l_B**2*m_eff**2 - 8*pi*D*d_eff*e**3*epsilon*l_B*m_eff**2 - e**4*m_eff**2 - 8*pi**2*epsilon**2*gamma_1**2*l_B**2*m_eff**2 - 16*pi**2*epsilon**2*hbar**2*l_B**2*m_eff**2*n*omega_B**2 - 8*pi**2*epsilon**2*hbar**2*l_B**2*m_eff**2*omega_B**2)/(8*pi**2*epsilon**2*l_B**2*m_eff**2))**3/108 + (-6*B**2*mu_B**2 + (-16*pi**2*B**2*e**2*epsilon**2*l_B**2 + 48*pi**2*B**2*epsilon**2*l_B**2*m_eff**2*mu_B**2 - 32*pi**2*B*D*d_eff*e**2*epsilon**2*l_B**2*m_eff - 8*pi*B*e**3*epsilon*l_B*m_eff - 16*pi**2*D**2*d_eff**2*e**2*epsilon**2*l_B**2*m_eff**2 - 8*pi*D*d_eff*e**3*epsilon*l_B*m_eff**2 - e**4*m_eff**2 - 8*pi**2*epsilon**2*gamma_1**2*l_B**2*m_eff**2 - 16*pi**2*epsilon**2*hbar**2*l_B**2*m_eff**2*n*omega_B**2 - 8*pi**2*epsilon**2*hbar**2*l_B**2*m_eff**2*omega_B**2)/(8*pi**2*epsilon**2*l_B**2*m_eff**2))*(B**4*e**4/m_eff**4 + 4*B**3*D*d_eff*e**4/m_eff**3 + B**3*e**5/(pi*epsilon*l_B*m_eff**3) + 6*B**2*D**2*d_eff**2*e**4/m_eff**2 + 3*B**2*D*d_eff*e**5/(pi*epsilon*l_B*m_eff**2) + 3*B**2*e**6/(8*pi**2*epsilon**2*l_B**2*m_eff**2) + B**2*e**2*gamma_1**2/m_eff**2 - 2*B**2*e**2*hbar**2*n*omega_B**2/m_eff**2 - B**2*e**2*hbar**2*omega_B**2/m_eff**2 + 4*B*D**3*d_eff**3*e**4/m_eff + 3*B*D**2*d_eff**2*e**5/(pi*epsilon*l_B*m_eff) + 3*B*D*d_eff*e**6/(4*pi**2*epsilon**2*l_B**2*m_eff) + 2*B*D*d_eff*e**2*gamma_1**2/m_eff - 4*B*D*d_eff*e**2*hbar**2*n*omega_B**2/m_eff - 2*B*D*d_eff*e**2*hbar**2*omega_B**2/m_eff + B*e**7/(16*pi**3*epsilon**3*l_B**3*m_eff) + B*e**3*gamma_1**2/(2*pi*epsilon*l_B*m_eff) - B*e**3*hbar**2*n*omega_B**2/(pi*epsilon*l_B*m_eff) - B*e**3*hbar**2*omega_B**2/(2*pi*epsilon*l_B*m_eff) + D**4*d_eff**4*e**4 + D**3*d_eff**3*e**5/(pi*epsilon*l_B) + 3*D**2*d_eff**2*e**6/(8*pi**2*epsilon**2*l_B**2) + D**2*d_eff**2*e**2*gamma_1**2 - 2*D**2*d_eff**2*e**2*hbar**2*n*omega_B**2 - D**2*d_eff**2*e**2*hbar**2*omega_B**2 + D*d_eff*e**7/(16*pi**3*epsilon**3*l_B**3) + D*d_eff*e**3*gamma_1**2/(2*pi*epsilon*l_B) - D*d_eff*e**3*hbar**2*n*omega_B**2/(pi*epsilon*l_B) - D*d_eff*e**3*hbar**2*omega_B**2/(2*pi*epsilon*l_B) + e**8/(256*pi**4*epsilon**4*l_B**4) + e**4*gamma_1**2/(16*pi**2*epsilon**2*l_B**2) - e**4*hbar**2*n*omega_B**2/(8*pi**2*epsilon**2*l_B**2) - e**4*hbar**2*omega_B**2/(16*pi**2*epsilon**2*l_B**2) + hbar**4*n**2*omega_B**4 + hbar**4*n*omega_B**4)/3 - (2*B*e*hbar**2*omega_B**2/m_eff + 2*D*d_eff*e*hbar**2*omega_B**2 + e**2*hbar**2*omega_B**2/(2*pi*epsilon*l_B))**2/8)**(1/3) - (-16*pi**2*B**2*e**2*epsilon**2*l_B**2 + 48*pi**2*B**2*epsilon**2*l_B**2*m_eff**2*mu_B**2 - 32*pi**2*B*D*d_eff*e**2*epsilon**2*l_B**2*m_eff - 8*pi*B*e**3*epsilon*l_B*m_eff - 16*pi**2*D**2*d_eff**2*e**2*epsilon**2*l_B**2*m_eff**2 - 8*pi*D*d_eff*e**3*epsilon*l_B*m_eff**2 - e**4*m_eff**2 - 8*pi**2*epsilon**2*gamma_1**2*l_B**2*m_eff**2 - 16*pi**2*epsilon**2*hbar**2*l_B**2*m_eff**2*n*omega_B**2 - 8*pi**2*epsilon**2*hbar**2*l_B**2*m_eff**2*omega_B**2)/(12*pi**2*epsilon**2*l_B**2*m_eff**2))/2 + sqrt(8*B**2*mu_B**2 + 2*(-(-6*B**2*mu_B**2 + (-16*pi**2*B**2*e**2*epsilon**2*l_B**2 + 48*pi**2*B**2*epsilon**2*l_B**2*m_eff**2*mu_B**2 - 32*pi**2*B*D*d_eff*e**2*epsilon**2*l_B**2*m_eff - 8*pi*B*e**3*epsilon*l_B*m_eff - 16*pi**2*D**2*d_eff**2*e**2*epsilon**2*l_B**2*m_eff**2 - 8*pi*D*d_eff*e**3*epsilon*l_B*m_eff**2 - e**4*m_eff**2 - 8*pi**2*epsilon**2*gamma_1**2*l_B**2*m_eff**2 - 16*pi**2*epsilon**2*hbar**2*l_B**2*m_eff**2*n*omega_B**2 - 8*pi**2*epsilon**2*hbar**2*l_B**2*m_eff**2*omega_B**2)/(8*pi**2*epsilon**2*l_B**2*m_eff**2))**3/108 + (-6*B**2*mu_B**2 + (-16*pi**2*B**2*e**2*epsilon**2*l_B**2 + 48*pi**2*B**2*epsilon**2*l_B**2*m_eff**2*mu_B**2 - 32*pi**2*B*D*d_eff*e**2*epsilon**2*l_B**2*m_eff - 8*pi*B*e**3*epsilon*l_B*m_eff - 16*pi**2*D**2*d_eff**2*e**2*epsilon**2*l_B**2*m_eff**2 - 8*pi*D*d_eff*e**3*epsilon*l_B*m_eff**2 - e**4*m_eff**2 - ...

# %%
eigenvals_expr[1]
# Out:
# Piecewise((B*mu_B - sqrt(4*B**2*mu_B**2 - 2*(-(-6*B**2*mu_B**2 + (-16*pi**2*B**2*e**2*epsilon**2*l_B**2 + 48*pi**2*B**2*epsilon**2*l_B**2*m_eff**2*mu_B**2 - 32*pi**2*B*D*d_eff*e**2*epsilon**2*l_B**2*m_eff - 8*pi*B*e**3*epsilon*l_B*m_eff - 16*pi**2*D**2*d_eff**2*e**2*epsilon**2*l_B**2*m_eff**2 - 8*pi*D*d_eff*e**3*epsilon*l_B*m_eff**2 - e**4*m_eff**2 - 8*pi**2*epsilon**2*gamma_1**2*l_B**2*m_eff**2 - 16*pi**2*epsilon**2*hbar**2*l_B**2*m_eff**2*n*omega_B**2 - 8*pi**2*epsilon**2*hbar**2*l_B**2*m_eff**2*omega_B**2)/(8*pi**2*epsilon**2*l_B**2*m_eff**2))**3/108 + (-6*B**2*mu_B**2 + (-16*pi**2*B**2*e**2*epsilon**2*l_B**2 + 48*pi**2*B**2*epsilon**2*l_B**2*m_eff**2*mu_B**2 - 32*pi**2*B*D*d_eff*e**2*epsilon**2*l_B**2*m_eff - 8*pi*B*e**3*epsilon*l_B*m_eff - 16*pi**2*D**2*d_eff**2*e**2*epsilon**2*l_B**2*m_eff**2 - 8*pi*D*d_eff*e**3*epsilon*l_B*m_eff**2 - e**4*m_eff**2 - 8*pi**2*epsilon**2*gamma_1**2*l_B**2*m_eff**2 - 16*pi**2*epsilon**2*hbar**2*l_B**2*m_eff**2*n*omega_B**2 - 8*pi**2*epsilon**2*hbar**2*l_B**2*m_eff**2*omega_B**2)/(8*pi**2*epsilon**2*l_B**2*m_eff**2))*(B**4*e**4/m_eff**4 + 4*B**3*D*d_eff*e**4/m_eff**3 + B**3*e**5/(pi*epsilon*l_B*m_eff**3) + 6*B**2*D**2*d_eff**2*e**4/m_eff**2 + 3*B**2*D*d_eff*e**5/(pi*epsilon*l_B*m_eff**2) + 3*B**2*e**6/(8*pi**2*epsilon**2*l_B**2*m_eff**2) + B**2*e**2*gamma_1**2/m_eff**2 - 2*B**2*e**2*hbar**2*n*omega_B**2/m_eff**2 - B**2*e**2*hbar**2*omega_B**2/m_eff**2 + 4*B*D**3*d_eff**3*e**4/m_eff + 3*B*D**2*d_eff**2*e**5/(pi*epsilon*l_B*m_eff) + 3*B*D*d_eff*e**6/(4*pi**2*epsilon**2*l_B**2*m_eff) + 2*B*D*d_eff*e**2*gamma_1**2/m_eff - 4*B*D*d_eff*e**2*hbar**2*n*omega_B**2/m_eff - 2*B*D*d_eff*e**2*hbar**2*omega_B**2/m_eff + B*e**7/(16*pi**3*epsilon**3*l_B**3*m_eff) + B*e**3*gamma_1**2/(2*pi*epsilon*l_B*m_eff) - B*e**3*hbar**2*n*omega_B**2/(pi*epsilon*l_B*m_eff) - B*e**3*hbar**2*omega_B**2/(2*pi*epsilon*l_B*m_eff) + D**4*d_eff**4*e**4 + D**3*d_eff**3*e**5/(pi*epsilon*l_B) + 3*D**2*d_eff**2*e**6/(8*pi**2*epsilon**2*l_B**2) + D**2*d_eff**2*e**2*gamma_1**2 - 2*D**2*d_eff**2*e**2*hbar**2*n*omega_B**2 - D**2*d_eff**2*e**2*hbar**2*omega_B**2 + D*d_eff*e**7/(16*pi**3*epsilon**3*l_B**3) + D*d_eff*e**3*gamma_1**2/(2*pi*epsilon*l_B) - D*d_eff*e**3*hbar**2*n*omega_B**2/(pi*epsilon*l_B) - D*d_eff*e**3*hbar**2*omega_B**2/(2*pi*epsilon*l_B) + e**8/(256*pi**4*epsilon**4*l_B**4) + e**4*gamma_1**2/(16*pi**2*epsilon**2*l_B**2) - e**4*hbar**2*n*omega_B**2/(8*pi**2*epsilon**2*l_B**2) - e**4*hbar**2*omega_B**2/(16*pi**2*epsilon**2*l_B**2) + hbar**4*n**2*omega_B**4 + hbar**4*n*omega_B**4)/3 - (2*B*e*hbar**2*omega_B**2/m_eff + 2*D*d_eff*e*hbar**2*omega_B**2 + e**2*hbar**2*omega_B**2/(2*pi*epsilon*l_B))**2/8)**(1/3) - (-16*pi**2*B**2*e**2*epsilon**2*l_B**2 + 48*pi**2*B**2*epsilon**2*l_B**2*m_eff**2*mu_B**2 - 32*pi**2*B*D*d_eff*e**2*epsilon**2*l_B**2*m_eff - 8*pi*B*e**3*epsilon*l_B*m_eff - 16*pi**2*D**2*d_eff**2*e**2*epsilon**2*l_B**2*m_eff**2 - 8*pi*D*d_eff*e**3*epsilon*l_B*m_eff**2 - e**4*m_eff**2 - 8*pi**2*epsilon**2*gamma_1**2*l_B**2*m_eff**2 - 16*pi**2*epsilon**2*hbar**2*l_B**2*m_eff**2*n*omega_B**2 - 8*pi**2*epsilon**2*hbar**2*l_B**2*m_eff**2*omega_B**2)/(12*pi**2*epsilon**2*l_B**2*m_eff**2))/2 - sqrt(8*B**2*mu_B**2 + 2*(-(-6*B**2*mu_B**2 + (-16*pi**2*B**2*e**2*epsilon**2*l_B**2 + 48*pi**2*B**2*epsilon**2*l_B**2*m_eff**2*mu_B**2 - 32*pi**2*B*D*d_eff*e**2*epsilon**2*l_B**2*m_eff - 8*pi*B*e**3*epsilon*l_B*m_eff - 16*pi**2*D**2*d_eff**2*e**2*epsilon**2*l_B**2*m_eff**2 - 8*pi*D*d_eff*e**3*epsilon*l_B*m_eff**2 - e**4*m_eff**2 - 8*pi**2*epsilon**2*gamma_1**2*l_B**2*m_eff**2 - 16*pi**2*epsilon**2*hbar**2*l_B**2*m_eff**2*n*omega_B**2 - 8*pi**2*epsilon**2*hbar**2*l_B**2*m_eff**2*omega_B**2)/(8*pi**2*epsilon**2*l_B**2*m_eff**2))**3/108 + (-6*B**2*mu_B**2 + (-16*pi**2*B**2*e**2*epsilon**2*l_B**2 + 48*pi**2*B**2*epsilon**2*l_B**2*m_eff**2*mu_B**2 - 32*pi**2*B*D*d_eff*e**2*epsilon**2*l_B**2*m_eff - 8*pi*B*e**3*epsilon*l_B*m_eff - 16*pi**2*D**2*d_eff**2*e**2*epsilon**2*l_B**2*m_eff**2 - 8*pi*D*d_eff*e**3*epsilon*l_B*m_eff**2 - e**4*m_eff**2 - ...

# %%
eigenvals_expr[2]
# Out:
# Piecewise((B*mu_B + sqrt(4*B**2*mu_B**2 - 2*(-(-6*B**2*mu_B**2 + (-16*pi**2*B**2*e**2*epsilon**2*l_B**2 + 48*pi**2*B**2*epsilon**2*l_B**2*m_eff**2*mu_B**2 - 32*pi**2*B*D*d_eff*e**2*epsilon**2*l_B**2*m_eff - 8*pi*B*e**3*epsilon*l_B*m_eff - 16*pi**2*D**2*d_eff**2*e**2*epsilon**2*l_B**2*m_eff**2 - 8*pi*D*d_eff*e**3*epsilon*l_B*m_eff**2 - e**4*m_eff**2 - 8*pi**2*epsilon**2*gamma_1**2*l_B**2*m_eff**2 - 16*pi**2*epsilon**2*hbar**2*l_B**2*m_eff**2*n*omega_B**2 - 8*pi**2*epsilon**2*hbar**2*l_B**2*m_eff**2*omega_B**2)/(8*pi**2*epsilon**2*l_B**2*m_eff**2))**3/108 + (-6*B**2*mu_B**2 + (-16*pi**2*B**2*e**2*epsilon**2*l_B**2 + 48*pi**2*B**2*epsilon**2*l_B**2*m_eff**2*mu_B**2 - 32*pi**2*B*D*d_eff*e**2*epsilon**2*l_B**2*m_eff - 8*pi*B*e**3*epsilon*l_B*m_eff - 16*pi**2*D**2*d_eff**2*e**2*epsilon**2*l_B**2*m_eff**2 - 8*pi*D*d_eff*e**3*epsilon*l_B*m_eff**2 - e**4*m_eff**2 - 8*pi**2*epsilon**2*gamma_1**2*l_B**2*m_eff**2 - 16*pi**2*epsilon**2*hbar**2*l_B**2*m_eff**2*n*omega_B**2 - 8*pi**2*epsilon**2*hbar**2*l_B**2*m_eff**2*omega_B**2)/(8*pi**2*epsilon**2*l_B**2*m_eff**2))*(B**4*e**4/m_eff**4 + 4*B**3*D*d_eff*e**4/m_eff**3 + B**3*e**5/(pi*epsilon*l_B*m_eff**3) + 6*B**2*D**2*d_eff**2*e**4/m_eff**2 + 3*B**2*D*d_eff*e**5/(pi*epsilon*l_B*m_eff**2) + 3*B**2*e**6/(8*pi**2*epsilon**2*l_B**2*m_eff**2) + B**2*e**2*gamma_1**2/m_eff**2 - 2*B**2*e**2*hbar**2*n*omega_B**2/m_eff**2 - B**2*e**2*hbar**2*omega_B**2/m_eff**2 + 4*B*D**3*d_eff**3*e**4/m_eff + 3*B*D**2*d_eff**2*e**5/(pi*epsilon*l_B*m_eff) + 3*B*D*d_eff*e**6/(4*pi**2*epsilon**2*l_B**2*m_eff) + 2*B*D*d_eff*e**2*gamma_1**2/m_eff - 4*B*D*d_eff*e**2*hbar**2*n*omega_B**2/m_eff - 2*B*D*d_eff*e**2*hbar**2*omega_B**2/m_eff + B*e**7/(16*pi**3*epsilon**3*l_B**3*m_eff) + B*e**3*gamma_1**2/(2*pi*epsilon*l_B*m_eff) - B*e**3*hbar**2*n*omega_B**2/(pi*epsilon*l_B*m_eff) - B*e**3*hbar**2*omega_B**2/(2*pi*epsilon*l_B*m_eff) + D**4*d_eff**4*e**4 + D**3*d_eff**3*e**5/(pi*epsilon*l_B) + 3*D**2*d_eff**2*e**6/(8*pi**2*epsilon**2*l_B**2) + D**2*d_eff**2*e**2*gamma_1**2 - 2*D**2*d_eff**2*e**2*hbar**2*n*omega_B**2 - D**2*d_eff**2*e**2*hbar**2*omega_B**2 + D*d_eff*e**7/(16*pi**3*epsilon**3*l_B**3) + D*d_eff*e**3*gamma_1**2/(2*pi*epsilon*l_B) - D*d_eff*e**3*hbar**2*n*omega_B**2/(pi*epsilon*l_B) - D*d_eff*e**3*hbar**2*omega_B**2/(2*pi*epsilon*l_B) + e**8/(256*pi**4*epsilon**4*l_B**4) + e**4*gamma_1**2/(16*pi**2*epsilon**2*l_B**2) - e**4*hbar**2*n*omega_B**2/(8*pi**2*epsilon**2*l_B**2) - e**4*hbar**2*omega_B**2/(16*pi**2*epsilon**2*l_B**2) + hbar**4*n**2*omega_B**4 + hbar**4*n*omega_B**4)/3 - (2*B*e*hbar**2*omega_B**2/m_eff + 2*D*d_eff*e*hbar**2*omega_B**2 + e**2*hbar**2*omega_B**2/(2*pi*epsilon*l_B))**2/8)**(1/3) - (-16*pi**2*B**2*e**2*epsilon**2*l_B**2 + 48*pi**2*B**2*epsilon**2*l_B**2*m_eff**2*mu_B**2 - 32*pi**2*B*D*d_eff*e**2*epsilon**2*l_B**2*m_eff - 8*pi*B*e**3*epsilon*l_B*m_eff - 16*pi**2*D**2*d_eff**2*e**2*epsilon**2*l_B**2*m_eff**2 - 8*pi*D*d_eff*e**3*epsilon*l_B*m_eff**2 - e**4*m_eff**2 - 8*pi**2*epsilon**2*gamma_1**2*l_B**2*m_eff**2 - 16*pi**2*epsilon**2*hbar**2*l_B**2*m_eff**2*n*omega_B**2 - 8*pi**2*epsilon**2*hbar**2*l_B**2*m_eff**2*omega_B**2)/(12*pi**2*epsilon**2*l_B**2*m_eff**2))/2 + sqrt(8*B**2*mu_B**2 + 2*(-(-6*B**2*mu_B**2 + (-16*pi**2*B**2*e**2*epsilon**2*l_B**2 + 48*pi**2*B**2*epsilon**2*l_B**2*m_eff**2*mu_B**2 - 32*pi**2*B*D*d_eff*e**2*epsilon**2*l_B**2*m_eff - 8*pi*B*e**3*epsilon*l_B*m_eff - 16*pi**2*D**2*d_eff**2*e**2*epsilon**2*l_B**2*m_eff**2 - 8*pi*D*d_eff*e**3*epsilon*l_B*m_eff**2 - e**4*m_eff**2 - 8*pi**2*epsilon**2*gamma_1**2*l_B**2*m_eff**2 - 16*pi**2*epsilon**2*hbar**2*l_B**2*m_eff**2*n*omega_B**2 - 8*pi**2*epsilon**2*hbar**2*l_B**2*m_eff**2*omega_B**2)/(8*pi**2*epsilon**2*l_B**2*m_eff**2))**3/108 + (-6*B**2*mu_B**2 + (-16*pi**2*B**2*e**2*epsilon**2*l_B**2 + 48*pi**2*B**2*epsilon**2*l_B**2*m_eff**2*mu_B**2 - 32*pi**2*B*D*d_eff*e**2*epsilon**2*l_B**2*m_eff - 8*pi*B*e**3*epsilon*l_B*m_eff - 16*pi**2*D**2*d_eff**2*e**2*epsilon**2*l_B**2*m_eff**2 - 8*pi*D*d_eff*e**3*epsilon*l_B*m_eff**2 - e**4*m_eff**2 - ...

# %%
eigenvals_expr[3]
# Out:
# Piecewise((B*mu_B + sqrt(4*B**2*mu_B**2 - 2*(-(-6*B**2*mu_B**2 + (-16*pi**2*B**2*e**2*epsilon**2*l_B**2 + 48*pi**2*B**2*epsilon**2*l_B**2*m_eff**2*mu_B**2 - 32*pi**2*B*D*d_eff*e**2*epsilon**2*l_B**2*m_eff - 8*pi*B*e**3*epsilon*l_B*m_eff - 16*pi**2*D**2*d_eff**2*e**2*epsilon**2*l_B**2*m_eff**2 - 8*pi*D*d_eff*e**3*epsilon*l_B*m_eff**2 - e**4*m_eff**2 - 8*pi**2*epsilon**2*gamma_1**2*l_B**2*m_eff**2 - 16*pi**2*epsilon**2*hbar**2*l_B**2*m_eff**2*n*omega_B**2 - 8*pi**2*epsilon**2*hbar**2*l_B**2*m_eff**2*omega_B**2)/(8*pi**2*epsilon**2*l_B**2*m_eff**2))**3/108 + (-6*B**2*mu_B**2 + (-16*pi**2*B**2*e**2*epsilon**2*l_B**2 + 48*pi**2*B**2*epsilon**2*l_B**2*m_eff**2*mu_B**2 - 32*pi**2*B*D*d_eff*e**2*epsilon**2*l_B**2*m_eff - 8*pi*B*e**3*epsilon*l_B*m_eff - 16*pi**2*D**2*d_eff**2*e**2*epsilon**2*l_B**2*m_eff**2 - 8*pi*D*d_eff*e**3*epsilon*l_B*m_eff**2 - e**4*m_eff**2 - 8*pi**2*epsilon**2*gamma_1**2*l_B**2*m_eff**2 - 16*pi**2*epsilon**2*hbar**2*l_B**2*m_eff**2*n*omega_B**2 - 8*pi**2*epsilon**2*hbar**2*l_B**2*m_eff**2*omega_B**2)/(8*pi**2*epsilon**2*l_B**2*m_eff**2))*(B**4*e**4/m_eff**4 + 4*B**3*D*d_eff*e**4/m_eff**3 + B**3*e**5/(pi*epsilon*l_B*m_eff**3) + 6*B**2*D**2*d_eff**2*e**4/m_eff**2 + 3*B**2*D*d_eff*e**5/(pi*epsilon*l_B*m_eff**2) + 3*B**2*e**6/(8*pi**2*epsilon**2*l_B**2*m_eff**2) + B**2*e**2*gamma_1**2/m_eff**2 - 2*B**2*e**2*hbar**2*n*omega_B**2/m_eff**2 - B**2*e**2*hbar**2*omega_B**2/m_eff**2 + 4*B*D**3*d_eff**3*e**4/m_eff + 3*B*D**2*d_eff**2*e**5/(pi*epsilon*l_B*m_eff) + 3*B*D*d_eff*e**6/(4*pi**2*epsilon**2*l_B**2*m_eff) + 2*B*D*d_eff*e**2*gamma_1**2/m_eff - 4*B*D*d_eff*e**2*hbar**2*n*omega_B**2/m_eff - 2*B*D*d_eff*e**2*hbar**2*omega_B**2/m_eff + B*e**7/(16*pi**3*epsilon**3*l_B**3*m_eff) + B*e**3*gamma_1**2/(2*pi*epsilon*l_B*m_eff) - B*e**3*hbar**2*n*omega_B**2/(pi*epsilon*l_B*m_eff) - B*e**3*hbar**2*omega_B**2/(2*pi*epsilon*l_B*m_eff) + D**4*d_eff**4*e**4 + D**3*d_eff**3*e**5/(pi*epsilon*l_B) + 3*D**2*d_eff**2*e**6/(8*pi**2*epsilon**2*l_B**2) + D**2*d_eff**2*e**2*gamma_1**2 - 2*D**2*d_eff**2*e**2*hbar**2*n*omega_B**2 - D**2*d_eff**2*e**2*hbar**2*omega_B**2 + D*d_eff*e**7/(16*pi**3*epsilon**3*l_B**3) + D*d_eff*e**3*gamma_1**2/(2*pi*epsilon*l_B) - D*d_eff*e**3*hbar**2*n*omega_B**2/(pi*epsilon*l_B) - D*d_eff*e**3*hbar**2*omega_B**2/(2*pi*epsilon*l_B) + e**8/(256*pi**4*epsilon**4*l_B**4) + e**4*gamma_1**2/(16*pi**2*epsilon**2*l_B**2) - e**4*hbar**2*n*omega_B**2/(8*pi**2*epsilon**2*l_B**2) - e**4*hbar**2*omega_B**2/(16*pi**2*epsilon**2*l_B**2) + hbar**4*n**2*omega_B**4 + hbar**4*n*omega_B**4)/3 - (2*B*e*hbar**2*omega_B**2/m_eff + 2*D*d_eff*e*hbar**2*omega_B**2 + e**2*hbar**2*omega_B**2/(2*pi*epsilon*l_B))**2/8)**(1/3) - (-16*pi**2*B**2*e**2*epsilon**2*l_B**2 + 48*pi**2*B**2*epsilon**2*l_B**2*m_eff**2*mu_B**2 - 32*pi**2*B*D*d_eff*e**2*epsilon**2*l_B**2*m_eff - 8*pi*B*e**3*epsilon*l_B*m_eff - 16*pi**2*D**2*d_eff**2*e**2*epsilon**2*l_B**2*m_eff**2 - 8*pi*D*d_eff*e**3*epsilon*l_B*m_eff**2 - e**4*m_eff**2 - 8*pi**2*epsilon**2*gamma_1**2*l_B**2*m_eff**2 - 16*pi**2*epsilon**2*hbar**2*l_B**2*m_eff**2*n*omega_B**2 - 8*pi**2*epsilon**2*hbar**2*l_B**2*m_eff**2*omega_B**2)/(12*pi**2*epsilon**2*l_B**2*m_eff**2))/2 - sqrt(8*B**2*mu_B**2 + 2*(-(-6*B**2*mu_B**2 + (-16*pi**2*B**2*e**2*epsilon**2*l_B**2 + 48*pi**2*B**2*epsilon**2*l_B**2*m_eff**2*mu_B**2 - 32*pi**2*B*D*d_eff*e**2*epsilon**2*l_B**2*m_eff - 8*pi*B*e**3*epsilon*l_B*m_eff - 16*pi**2*D**2*d_eff**2*e**2*epsilon**2*l_B**2*m_eff**2 - 8*pi*D*d_eff*e**3*epsilon*l_B*m_eff**2 - e**4*m_eff**2 - 8*pi**2*epsilon**2*gamma_1**2*l_B**2*m_eff**2 - 16*pi**2*epsilon**2*hbar**2*l_B**2*m_eff**2*n*omega_B**2 - 8*pi**2*epsilon**2*hbar**2*l_B**2*m_eff**2*omega_B**2)/(8*pi**2*epsilon**2*l_B**2*m_eff**2))**3/108 + (-6*B**2*mu_B**2 + (-16*pi**2*B**2*e**2*epsilon**2*l_B**2 + 48*pi**2*B**2*epsilon**2*l_B**2*m_eff**2*mu_B**2 - 32*pi**2*B*D*d_eff*e**2*epsilon**2*l_B**2*m_eff - 8*pi*B*e**3*epsilon*l_B*m_eff - 16*pi**2*D**2*d_eff**2*e**2*epsilon**2*l_B**2*m_eff**2 - 8*pi*D*d_eff*e**3*epsilon*l_B*m_eff**2 - e**4*m_eff**2 - ...
